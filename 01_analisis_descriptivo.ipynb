# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# leemos el dataset
data = pd.read_csv('data/df_train_small.csv')

# %%
# analisis descriptivo.

# %%
# 1 numero de filas y columnas
data.shape
# Out:
# (80000, 151)

# %%
# info de las columnas, tipos de datos, valores nulos, etc
data.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 151 columns):
#  #    Column                                      Non-Null Count  Dtype
# ---   ------                                      --------------  -----
#  0    id                                          80000 non-null  int64
#  1    member_id                                   0 non-null      float64
#  2    loan_amnt                                   80000 non-null  float64
#  3    funded_amnt                                 80000 non-null  float64
#  4    funded_amnt_inv                             80000 non-null  float64
#  5    term                                        80000 non-null  str
#  6    int_rate                                    80000 non-null  float64
#  7    installment                                 80000 non-null  float64
#  8    grade                                       80000 non-null  str
#  9    sub_grade                                   80000 non-null  str
# ...

# %%
## Cuantos nulos hay en cada columna
data.isnull().sum().to_frame(name='num_nulls').sort_values(by='num_nulls', ascending=False)/800
# Out:
#                                             num_nulls
# next_pymnt_d                                100.00000
# member_id                                   100.00000
# orig_projected_additional_accrued_interest   99.71375
# sec_app_mths_since_last_major_derog          99.70500
# hardship_end_date                            99.54625
# ...                                               ...
# open_acc                                      0.00000
# inq_last_6mths                                0.00000
# fico_range_high                               0.00000
# fico_range_low                                0.00000
# id                                            0.00000
#
# [151 rows x 1 columns]

# %%
data.describe()
# Out:
#                  id  member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  8.000000e+04        0.0  80000.000000  80000.000000     80000.000000
# mean   5.292394e+07        NaN  14376.815000  14368.696250     14345.974336
# std    3.554961e+07        NaN   8659.228296   8655.973151      8657.918632
# min    6.510400e+04        NaN    725.000000    725.000000         0.000000
# 25%    1.797149e+07        NaN   7800.000000   7800.000000      7800.000000
# 50%    5.555509e+07        NaN  12000.000000  12000.000000     12000.000000
# 75%    7.755545e+07        NaN  20000.000000  20000.000000     20000.000000
# max    1.263872e+08        NaN  40000.000000  40000.000000     40000.000000
#
#            int_rate   installment    annual_inc           dti   delinq_2yrs  \
# count  80000.000000  80000.000000  8.000000e+04  79983.000000  80000.000000
# mean      13.218272    437.234301  7.626131e+04     18.314891      0.325362
# ...

# %%
data.describe(include='all').T
# Out:
#                          count unique       top freq           mean  \
# id                     80000.0    NaN       NaN  NaN  52923940.2819
# member_id                  0.0    NaN       NaN  NaN            NaN
# loan_amnt              80000.0    NaN       NaN  NaN      14376.815
# funded_amnt            80000.0    NaN       NaN  NaN    14368.69625
# funded_amnt_inv        80000.0    NaN       NaN  NaN   14345.974336
# ...                        ...    ...       ...  ...            ...
# settlement_status         2115      3  COMPLETE  913            NaN
# settlement_date           2115     63  Jan-2019  108            NaN
# settlement_amount       2115.0    NaN       NaN  NaN    4844.686426
# settlement_percentage   2115.0    NaN       NaN  NaN      47.645787
# settlement_term         2115.0    NaN       NaN  NaN      13.165485
#
#                                    std      min          25%         50%  \
# id                     35549612.986589  65104.0  17971494.25  55555090.5
# ...

# %%
# seleccionar las variables categoricas
categorical_cols = data.select_dtypes(include='object').columns
categorical_cols
# Out:
# /var/folders/_0/0zwytxv51nb3c6wxtthk3bwh0000gn/T/ipykernel_1666/1501079374.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = data.select_dtypes(include='object').columns
# Index(['term', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'earliest_cr_line', 'initial_list_status', 'last_pymnt_d',
#        'last_credit_pull_d', 'application_type', 'verification_status_joint',
# ...

# %%
len(categorical_cols)
# Out:
# 36

# %%
# analizar cardinalidad de las variables categoricas
data[categorical_cols].nunique().to_frame(name='num_unique').sort_values(by='num_unique', ascending=False)
# Out:
#                            num_unique
# url                             80000
# emp_title                       36885
# desc                             7739
# title                            5667
# zip_code                          872
# earliest_cr_line                  634
# sec_app_earliest_cr_line          287
# last_pymnt_d                      127
# issue_d                           124
# last_credit_pull_d                122
# settlement_date                    63
# debt_settlement_flag_date          56
# addr_state                         50
# sub_grade                          35
# hardship_end_date                  23
# hardship_start_date                20
# payment_plan_start_date            20
# purpose                            14
# emp_length                         11
# hardship_reason                     9
# grade                               7
# home_ownership                      6
# hardship_loan_status                4
# verification_status                 3
# ...

# %%
# analizar emp_title
data['emp_title'].nunique()
data['emp_title'].value_counts().head(100)
# Out:
# emp_title
# Teacher               1221
# Manager               1176
# Owner                  615
# Registered Nurse       548
# Supervisor             524
#                       ...
# Marketing Manager       54
# Software Developer      54
# operator                54
# Team Leader             53
# Officer                 53
# Name: count, Length: 100, dtype: int64

# %%
from skrub import TableReport
TableReport(data, max_plot_columns=151)
# Out:
# Processing column 151 / 151
# <TableReport: use .open() to display>

# %%
# vamos comparar variables numericas con la variable objetivo loan_status
numerical_cols = data.select_dtypes(include='number').columns

for col in numerical_cols[4:6]:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='loan_status', y=col, data=data)
    plt.title(f'Boxplot of {col} by loan_status')
    plt.show()

# %%
# grafico de densisdad de las variables numericas con respecto a la variable objetivo
for col in numerical_cols[4:6]:
    plt.figure(figsize=(10, 6))
    sns.kdeplot(data=data, x=col, hue='loan_status', fill=True)
    plt.title(f'Density Plot of {col} by loan_status')
    plt.show()

# %%
# compara variables categoricas con la variable objetivo.
# pintamos un heatmap usand pd.crosstab para cada variable categorica con la variable objetivo loan_status
for col in categorical_cols[:3]:
    plt.figure(figsize=(10, 6))
    crosstab = pd.crosstab(data[col], data['loan_status'], normalize=True)
    sns.heatmap(crosstab, annot=True, cmap='Blues', fmt='.2f')
    plt.title(f'Heatmap of {col} by loan_status')
    plt.ylabel(col)
    plt.xlabel('loan_status')
    plt.show()
